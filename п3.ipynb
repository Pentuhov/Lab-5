# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
labels = ['Центральный', 'Северный', 'Северо-Западный', 'Северо-Восточный', 'Южный', 'Юго-Западный', 'Юго-Восточный', 'Западный', 'Восточный']
values = [29.00, 12.00, 5.00, 8.00, 11.00, 7.00, 9.00, 9.00, 10.00]

# %%
fig1, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(values, labels=labels, autopct='%1.2f%%')
ax.pie(values, labels=labels)
ax.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0));
plt.show()
